# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
input_path = 'input_dataset/mitsubishi_imiev.csv'

# %%
import chardet
with open(input_path, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7158366411168902, 'language': ''}

# %%
df = pd.read_csv(input_path,encoding='ISO-8859-1')

# %%
df.head()
# Out:
#   manufacturer   model version  power(kW)   fuel_date  odometer  \
# 0   Mitsubishi  i-MiEV  i-MiEV         49  07.02.2019    176977
# 1   Mitsubishi  i-MiEV  i-MiEV         49  06.02.2019    176926
# 2   Mitsubishi  i-MiEV  i-MiEV         49  05.02.2019    176876
# 3   Mitsubishi  i-MiEV  i-MiEV         49  04.02.2019    176824
# 4   Mitsubishi  i-MiEV  i-MiEV         49  03.02.2019    176772
#
#    trip_distance(km)  quantity(kWh)    fuel_type     tire_type  city  \
# 0               50.7           6.50  Electricity  Winter tires     1
# 1               49.9           7.30  Electricity  Winter tires     1
# 2               51.5           7.10  Electricity  Winter tires     1
# 3               52.5           7.40  Electricity  Winter tires     1
# 4                0.5           1.65  Electricity  Winter tires     1
#
#    motor_way  country_roads driving_style  consumption(kWh/100km)  A/C  \
# 0          0              1        Normal                     NaN    0
# 1          0              1        Normal                   14.63    0
# 2          0              1        Normal                   13.79    0
# 3          0              1        Normal                   14.10    0
# 4          0              0        Normal                   14.47    0
#
#    park_heating  avg_speed(km/h)  ecr_deviation  \
# 0             0              NaN            NaN
# 1             0              NaN          -0.37
# 2             0              NaN          -1.21
# 3             0              NaN          -0.90
# 4             0              NaN          -0.53
#
#                                            fuel_note
# 0  Noch 6 Balken, 33km Reichweite, Mainova Ökostr...
# 1  Noch 5 Balken, 30km Reichweite, Mainova Ökostr...
# 2  Noch 6B, 36km RRW, Batterie 8-11°C, 9,3°C, 41,...
# 3  Noch 5 Balken, 30km Reichweite, Mainova Ökostr...
# 4  Noch 15 Balken, 75km Reichweite, 85,5%, Batter...
